# %% [markdown]
# # EDA a partir de la API de MELI
# ### Exploración y análisis
# <a id="top"></a>
# Autor: Mathiews Flores Zavala
#
# <p> En esta notebook, voy a explorar los resultados de las publicaciones de MELI meduante su API de acceso público. Y se proseguirá a obtener un dataset para trabajar a posteriori, y un análisis exploratorio de los datos</p>
#
# ## Tabla de Contenidos
# 1. <a href="#1">Data Wrangling</a>
# * 1.1 <a href="#1.1">Importando librerías y datos</a>
# * 1.2 <a href="#1.2">Explorando los datos </a>
# * 1.3 <a href="#1.3">Armando el dataset</a>
# * 1.4 <a href="#1.4">Analisis del dataset</a>
#     * 1.4.1 <a href="#1.4.1">Visualizacion de datos</a>
#     * 1.4.2 <a href="#1.4.2">Estudio de correlaciones</a>
#     * 1.4.3 <a href="#1.4.3">Respoindiendo algunas preguntas de negocios</a>
#
# 2. <a href="#2">Identificado data extra (*Get the Data*)</a>
# * 2.1 <a href='#2.1'>Extraccion de datos extra</a>
#
# 3. <a href="#3">Conclusion de Parte I</a>
# * 3.1 <a href='#3.1'>Preparacion del data set final</a>
# * 3.2 <a href='#3.2'>Comentarios finales</a>

# %% [markdown]
# ---
# <a href="#top">Back to Index</a>
# <a id="1"></a>
# ### 1) Data Wrangling
# <a id="1.1"></a>
# #### 1.1) Importando librerias y datos

# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

from time import time, sleep
import re

#from bs4 import BeautifulSoup

# %% [markdown]
# Consulto la API de Mercado Libre publica mediante búsquedas. En esta instacia me focalizaré en recopilar datos para componer una muestra de la población de publicaciones disponibles de la API de MELI

# %%
url = 'https://api.mercadolibre.com/sites/MLA/search?q=tv%204k'
result = requests.get(url)
type(result)
# Out:
# requests.models.Response

# %%
print('La conexión se logro con exito: ', str(result.status_code == 200))
# Out:
# La conexión se logro con exito:  True

# %%
# me fijo en el kas keys de contenido que hay, para darme una idea de lo que puedo obtener y lo que me interesa
data1 = result.json()
data1.keys()
# Out:
# dict_keys(['site_id', 'country_default_time_zone', 'query', 'paging', 'results', 'sort', 'available_sorts', 'filters', 'available_filters'])

# %%
data1['paging']
# Out:
# {'total': 3363, 'primary_results': 1000, 'offset': 0, 'limit': 50}

# %%
print( data1['paging']['total'] )
vector_data1 = list( range(0, data1['paging']['total'] , 50) )
# Out:
# 3363

# %%
# verificamos la cantidad de registros entregados en la consulta
print('La cantidad de registros por consutla son ',str(len(data1['results'])))
# Out:
# La cantidad de registros por consutla son  50

# %% [markdown]
# La busqueda inicial arroja 1000 registros de un total de 3455 de los mismos, donde el límite esta en 50 datos por consulta.
# Para no saturar el servicio con las consultas, se explorará inicialmente el contenido del que se dispone, posteriormente se extraera datos para armar un data set orientado hacia elementos digitales (televisores, telefonos, notebooks, tablets)

# %% [markdown]
# <a id="1.2"></a>
# #### 1.2) Explorando los datos

# %%
# explioramos los resultados
data1['results'][1]
# Out:
# {'id': 'MLA926081002',
#  'site_id': 'MLA',
#  'title': 'Smart Tv Bgh 50 4k  Uhd Android',
#  'seller': {'id': 608846165,
#   'permalink': 'http://perfil.mercadolibre.com.ar/MERCADOLIBRE+ELECTRONICA_AR',
#   'registration_date': '2020-07-13T13:21:30.000-04:00',
#   'car_dealer': False,
#   'real_estate_agency': False,
#   'tags': ['brand',
#    'user_info_verified',
#    'large_seller',
#    'credits_profile',
#    'messages_as_seller'],
#   'seller_reputation': {'transactions': {'total': 637665,
#     'canceled': 29475,
#     'period': 'historic',
#     'ratings': {'negative': 0.06, 'positive': 0.93, 'neutral': 0.01},
#     'completed': 608190},
#    'power_seller_status': 'platinum',
#    'metrics': {'claims': {'rate': 0.0087, 'value': 1092, 'period': '60 days'},
#     'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '60 days'},
#     'sales': {'period': '60 days', 'completed': 120385},
#     'cancellations': {'rate': 0, 'value': 1, 'period': '60 days'}},
#    'level_id': '5_green'}},
#  'price': 62999,
#  'prices': {'id': 'MLA926081002',
#   'prices': [{'id': '45',
#     'type': 'standard',
#     'conditions': {'context_restrictions': [],
#      'start_time': None,
#      'end_time': None,
#      'eligible': True},
#     'amount': 62999,
#     'regular_amount': None,
#     'currency_id': 'ARS',
#     'exchange_rate_context': 'DEFAULT',
#     'metadata': {},
#     'last_updated': '2021-08-13T14:40:33Z'}],
#   'presentation': {'display_currency': 'ARS'},
#   'payment_method_prices': [],
#   'reference_prices': [{'id': '56',
#     'type': 'was',
#     'conditions': {'context_restrictions': [],
#      'start_time': '2021-08-22T04:15:52Z',
#      'end_time': '2021-08-25T04:15:52Z',
#      'eligible': True},
#     'amount': 49999,
#     'currency_id': 'ARS',
#     'exchange_rate_context': 'DEFAULT',
#     'tags': [],
#     'last_updated': '2021-08-22T04:15:52Z'}],
#   'purchase_discounts': []},
#  'sale_price': None,
#  'currency_id': 'ARS',
#  'available_quantity': 250,
#  'sold_quantity': 250,
#  'buying_mode': 'buy_it_now',
#  'listing_type_id': 'gold_pro',
#  'stop_time': '2041-07-28T20:29:12.000Z',
#  'condition': 'new',
#  'permalink': 'https://articulo.mercadolibre.com.ar/MLA-926081002-smart-tv-bgh-50-4k-uhd-android-_JM',
#  'thumbnail': 'http://http2.mlstatic.com/D_893006-MLA46430431526_062021-I.jpg',
#  'thumbnail_id': '893006-MLA46430431526_062021',
#  'accepts_mercadopago': True,
#  'installments': {'quantity': 12,
#   'amount': 5249.92,
#   'rate': 0,
#   'currency_id': 'ARS'},
#  'address': {'state_id': 'AR-B',
#   'state_name': 'Buenos Aires',
#   'city_id': None,
#   'city_name': 'Villa Celina'},
#  'shipping': {'free_shipping': True,
#   'mode': 'me2',
#   'tags': ['fulfillment', 'mandatory_free_shipping'],
#   'logistic_type': 'fulfillment',
#   'store_pick_up': False},
#  'seller_address': {'id': '',
#   'comment': '',
#   'address_line': '',
#   'zip_code': '',
#   'country': {'id': 'AR', 'name': 'Argentina'},
#   'state': {'id': 'AR-B', 'name': 'Buenos Aires'},
#   'city': {'id': None, 'name': 'Villa Celina'},
#   'latitude': '',
#   'longitude': ''},
#  'attributes': [{'name': 'Marca',
#    'value_name': 'BGH',
#    'values': [{'source': 8748668969142,
#      'id': '5601',
#      'name': 'BGH',
#      'struct': None}],
#    'attribute_group_id': 'MAIN',
#    'attribute_group_name': 'Principales',
#    'source': 8748668969142,
#    'id': 'BRAND',
#    'value_id': '5601',
#    'value_struct': None},
#   {'value_struct': None,
#    'values': [{'id': None,
#      'name': 'B5021UH6A',
#      'struct': None,
#      'source': 8748668969142}],
#    'source': 8748668969142,
#    'id': 'MODEL',
#    'name': 'Modelo',
#    'value_name': 'B5021UH6A',
#    'value_id': None,
#    'attribute_group_id': 'MAIN',
#    'attribute_group_name': 'Principales'},
#   {'name': 'Modelo alfanumérico',
#    'value_name': 'B5021UH6A',
#    'values': [{'name': 'B5021UH6A',
#      'struct': None,
#      'source': 8748668969142,
#      'id': None}],
#    'attribute_group_name': 'Otros',
#    'source': 8748668969142,
#    'id': 'ALPHANUMERIC_MODEL',
#    'value_id': None,
#    'value_struct': None,
#    'attribute_group_id': 'OTHERS'},
#   {'value_struct': None,
#    'values': [{'name': 'Nuevo', 'struct': None, 'source': 1, 'id': '2230284'}],
#    'attribute_group_id': 'OTHERS',
#    'source': 1,
#    'value_id': '2230284',
#    'name': 'Condición del ítem',
#    'value_name': 'Nuevo',
#    'attribute_group_name': 'Otros',
#    'id': 'ITEM_CONDITION'},
#   {'id': 'LINE',
#    'name': 'Línea',
#    'value_id': '7949998',
#    'value_struct': None,
#    'values': [{'name': 'UHD',
#      'struct': None,
#      'source': 8748668969142,
#      'id': '7949998'}],
#    'value_name': 'UHD',
#    'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Otros',
#    'source': 8748668969142},
#   {'name': 'Potencia máxima de los parlantes',
#    'attribute_group_name': 'Otros',
#    'id': 'MAX_SPEAKERS_POWER',
#    'value_id': None,
#    'value_name': '20 W',
#    'value_struct': {'number': 20, 'unit': 'W'},
#    'values': [{'id': None,
#      'name': '20 W',
#      'struct': {'number': 20, 'unit': 'W'},
#      'source': 3376461333454861}],
#    'attribute_group_id': 'OTHERS',
#    'source': 3376461333454861},
#   {'id': 'PACKAGE_LENGTH',
#    'value_id': None,
#    'value_struct': {'unit': 'cm', 'number': 15},
#    'attribute_group_id': 'OTHERS',
#    'name': 'Largo del paquete',
#    'value_name': '15 cm',
#    'values': [{'source': 4333789534002961,
#      'id': None,
#      'name': '15 cm',
#      'struct': {'number': 15, 'unit': 'cm'}}],
#    'attribute_group_name': 'Otros',
#    'source': 4333789534002961},
#   {'attribute_group_name': 'Otros',
#    'source': 4333789534002961,
#    'name': 'Peso del paquete',
#    'value_name': '10000 g',
#    'value_struct': {'number': 10000, 'unit': 'g'},
#    'values': [{'source': 4333789534002961,
#      'id': None,
#      'name': '10000 g',
#      'struct': {'number': 10000, 'unit': 'g'}}],
#    'attribute_group_id': 'OTHERS',
#    'id': 'PACKAGE_WEIGHT',
#    'value_id': None},
#   {'attribute_group_id': 'OTHERS',
#    'attribute_group_name': 'Otros',
#    'source': 3376461333454861,
#    'id': 'WEIGHT',
#    'name': 'Peso',
#    'value_id': None,
#    'value_struct': {'number': 9.3, 'unit': 'kg'},
#    'value_name': '9.3 kg',
#    'values': [{'id': None,
#      'name': '9.3 kg',
#      'struct': {'number': 9.3, 'unit': 'kg'},
#      'source': 3376461333454861}]}],
#  'differential_pricing': {'id': 35713319},
#  'original_price': None,
#  'category_id': 'MLA1002',
#  'official_store_id': 1938,
#  'domain_id': 'MLA-TELEVISIONS',
#  'catalog_product_id': None,
#  'tags': ['ahora-12',
#   'catalog_product_candidate',
#   'extended_warranty_eligible',
#   'good_quality_picture',
#   'good_quality_thumbnail',
#   'loyalty_discount_eligible',
#   'immediate_payment',
#   'shipping_guaranteed'],
#  'order_backend': 2,
#  'use_thumbnail_id': True}

# %% [markdown]
# Observando la documentación, vemos algunas de los atributos de las publicaciones, como el *id* y *título* de cada una de ellas,
# informacion del vendedor o *seller* (con su respectivo ID, y sitio en mercado Libre, su fecha de registro, entre otros).
# Algunos valores interesantes de esta documentación consiste en la reputación del vendedor, ratings, entre otros.
#
# Otros quizá resuleten no tan informativos, como *prices*, que además de contener algo de iformación redundante como *price, currency* contiene cierta metadata que puede no aportar mucho en una instancia temprana. De esta manera hay otros como *presentation, payment_method_prices*

# %%
# hago otra consulta
url = 'https://api.mercadolibre.com/sites/MLA/search?q=tv%204k&offset=340'
result2 = requests.get(url)
data2 = result2.json()

# %% [markdown]
# Se puede obtener hasta 1000 datos sin problemas, que corresponde a los primary_results, posterior a eso necesito el ID_USER para poder acceder a un código para mi url para acceder al resto de los datos. Por ahora voy a dejarlo en 2do plano.
# Y realizaré consultas de hasta 1000 registros, siendo conciente que estos 1000 resultados estan inlfuenciados por el propio algoritmo del motor de búsqueda de MELI.

# %%
# exploramos los datos del primer dataset
df1 = pd.DataFrame(data1['results'])
df1
# Out:
#               id site_id                                              title  \
# 0   MLA898844422     MLA  Smart Tv Samsung Series 7 Un50tu7000gczb Led 4...
# 1   MLA926081002     MLA                    Smart Tv Bgh 50 4k  Uhd Android
# 2   MLA935211923     MLA         Smart Tv Hyundai Hyled-50uhd5a 4k 50  220v
# 3   MLA884683677     MLA                Smart Tv Samsung 50 4k Uhd 50tu7000
# 4   MLA878666563     MLA  Smart Tv Philips 6600 Series 50pud6654/77 Led ...
# 5   MLA921695477     MLA   Chromecast With Google Tv  De Voz 4k 8gb  Sno...
# 6   MLA898843595     MLA  Smart Tv Samsung Series 7 Un43tu7000gczb Led 4...
# 7   MLA924494260     MLA          Smart Tv Sansei Tds2150ui Led 4k Uhd 50''
# 8   MLA935203327     MLA         Smart Tv Tcl L42s6500 Led Full Hd 42  220v
# 9   MLA921848291     MLA                Smart Tv Noblex Dk55x6500 Led 4k 55
# 10  MLA877436109     MLA  Smart Tv Tedge Led 50 Pulgadas Ntv504k Led 4k ...
# 11  MLA919581387     MLA           Smart Tv Tcl 50p715 Led 4k 50  100v/240v
# 12  MLA919747481     MLA                     Smart Tv LG 43 43un7310 4k Uhd
# 13  MLA840417930     MLA           Smart Tv 50 Pulgadas Ultra Hd 4k - Tedge
# 14  MLA923198215     MLA  Smart Tv Samsung Series 6 Qn55q60tagczb Qled 4...
# 15  MLA885495289     MLA                Smart Tv Samsung 43 4k Uhd 43tu7000
# 16  MLA881593414     MLA   Amazon Fire Tv Stick 4k  De Voz 4k 8gb  Negro...
# 17  MLA917447444     MLA                    Smart Tv Tcl 50p715 Dled 4k 50
# 18  MLA921845745     MLA                Smart Tv Noblex Dk50x6500 Led 4k 50
# 19  MLA918449426     MLA            Smart Tv Sansei Tds2150ui Led 4k Uhd 50
# 20  MLA910313990     MLA   Chromecast With Google Tv  De Voz 4k 8gb  Sno...
# 21  MLA854241364     MLA   Xiaomi Mi Box S Mdz-22-ab  De Voz 4k 8gb  Neg...
# 22  MLA915986933     MLA     Android Tv Noblex 50 Pulgadas 4k Uhd Dm50x7550
# 23  MLA923246389     MLA  Smart Tv 55 Tcl Uhd 4k Android Chromecast Buil...
# 24  MLA886191424     MLA           Smart Tv Admiral Ad43e20 Led Full Hd 43
# 25  MLA885005578     MLA   Samsung Televisor Smart 50   4k Crystal Uhd U...
# 26  MLA869878429     MLA  Smart Tv Philips 5100 Series 49pfg5102/77 Led ...
# 27  MLA881157553     MLA  Tv Box Gadnic Tx-1200 Smtv0030  Estándar 4k 16...
# 28  MLA921735094     MLA  Smart Tv Led LG 43 43un7310 Uhd 4k Thinq Ai Hd...
# 29  MLA931108901     MLA  Smart Tv Led 50 Rca And50fxuhd 4k Android Tv A...
# 30  MLA918036110     MLA           Smart Tv Led 4k Uhd 55  Hisense 55a64gsv
# 31  MLA925125866     MLA  Smart Tv Noblex Dm50x7550 Led 4k 50'' Android ...
# 32  MLA929136213     MLA  Televisor Smart Hitachi 50  4k Ultra Hd Androi...
# 33  MLA920190973     MLA            Smart Tv 4k Uhd Samsung 65  Un65tu7000g
# 34  MLA928442798     MLA         Smart Tv Philco Pld50us21api Led 4k Uhd 50
# 35  MLA919437561     MLA        Smart Tv LG Ai Thinq 50un7310psc Led 4k 50
# 36  MLA920278921     MLA  Smart Tv Philips 6700 Series 55pug6703/77 Led ...
# 37  MLA922859072     MLA  Smart Tv Led Philips 50  6600 Series 50pud6654...
# 38  MLA907653709     MLA  Smart Tv Philips 6600 Series 50pug6654/78 Led ...
# 39  MLA932556983     MLA  Smart Tv Noblex Dm55x7550 Led 4k 55'' Android ...
# 40  MLA895899643     MLA  Smart Tv Philips 6600 Series 55pug6654/78 Led ...
# 41  MLA912582257     MLA   Amazon Fire Tv Stick 4k Cr Voz 4k 8gb  Negro ...
# 42  MLA918615346     MLA                  Smart Tv 4k Uhd 50  Bgh B5021uh6a
# 43  MLA798312416     MLA  Control Remoto Smart Tv Para Samsung Curvo 4k ...
# 44  MLA932728972     MLA   Smart Tv Sanyo Lce55su1500 Led 4k 55'' Bluetooth
# 45  MLA880314704     MLA  Cable Hdmi 2.0 Premium. 4k/4k Ultra 3d/lcd/tv/...
# 46  MLA927442698     MLA        Smart Tv Led 4k 55'' Noblex Dk55x6500 Delta
# 47  MLA899436143     MLA  Smart Tv Samsung Series Q60 Qn55q60ta Qled 4k ...
# 48  MLA854230305     MLA  Xiaomi Mi Tv Box S 2gb Ram Tv 4k 8gb Control R...
# 49  MLA899857287     MLA  Smart Tv Philips 58pud6654/77 Led 4k 58  110v/...
#
#                                                seller      price  \
# 0   {'id': 608846165, 'permalink': 'http://perfil....   75999.00
# 1   {'id': 608846165, 'permalink': 'http://perfil....   62999.00
# 2   {'id': 608846165, 'permalink': 'http://perfil....   69999.00
# 3   {'id': 608846165, 'permalink': 'http://perfil....   75999.00
# 4   {'id': 608846165, 'permalink': 'http://perfil....   62999.00
# 5   {'id': 279736282, 'permalink': 'http://perfil....   11399.00
# 6   {'id': 608846165, 'permalink': 'http://perfil....   63999.00
# 7   {'id': 256324891, 'permalink': 'http://perfil....   53999.00
# 8   {'id': 608846165, 'permalink': 'http://perfil....   41999.00
# 9   {'id': 256324891, 'permalink': 'http://perfil....   93799.00
# 10  {'id': 417972986, 'permalink': 'http://perfil....   54999.00
# 11  {'id': 608846165, 'permalink': 'http://perfil....   67999.00
# 12  {'id': 211081461, 'permalink': 'http://perfil....   56999.05
# 13  {'id': 417972986, 'permalink': 'http://perfil....   54999.00
# 14  {'id': 452287402, 'permalink': 'http://perfil....  110999.00
# 15  {'id': 608846165, 'permalink': 'http://perfil....   63999.00
# 16  {'id': 218165061, 'permalink': 'http://perfil....   10849.00
# 17  {'id': 608846165, 'permalink': 'http://perfil....   67999.00
# 18  {'id': 256324891, 'permalink': 'http://perfil....   64499.00
# 19  {'id': 256324891, 'permalink': 'http://perfil....   66999.00
# 20  {'id': 318494504, 'permalink': 'http://perfil....   11399.00
# 21  {'id': 85719635, 'permalink': 'http://perfil.m...   12779.10
# 22  {'id': 15604260, 'permalink': 'http://perfil.m...   62599.00
# 23  {'id': 39144101, 'permalink': 'http://perfil.m...   88999.00
# 24  {'id': 143125485, 'permalink': 'http://perfil....   42499.00
# 25  {'id': 172753273, 'permalink': 'http://perfil....   75999.00
# 26  {'id': 183212103, 'permalink': 'http://perfil....   63438.78
# 27  {'id': 39144101, 'permalink': 'http://perfil.m...    7499.00
# 28  {'id': 71229887, 'permalink': 'http://perfil.m...   59999.00
# 29  {'id': 288753228, 'permalink': 'http://perfil....   66999.00
# 30  {'id': 139060460, 'permalink': 'http://perfil....   87999.00
# 31  {'id': 256324891, 'permalink': 'http://perfil....   67699.00
# 32  {'id': 82521850, 'permalink': 'http://perfil.m...   69999.00
# 33  {'id': 143125485, 'permalink': 'http://perfil....  129999.00
# 34  {'id': 256324891, 'permalink': 'http://perfil....   63999.00
# 35  {'id': 274214713, 'permalink': 'http://perfil....   69999.00
# 36  {'id': 457761714, 'permalink': 'http://perfil....   84999.00
# 37  {'id': 323800888, 'permalink': 'http://perfil....   62999.00
# 38  {'id': 236167730, 'permalink': 'http://perfil....   66000.00
# 39  {'id': 256324891, 'permalink': 'http://perfil....   75499.00
# 40  {'id': 9877009, 'permalink': 'http://perfil.me...   80999.90
# 41  {'id': 51553752, 'permalink': 'http://perfil.m...   10998.00
# 42  {'id': 139060460, 'permalink': 'http://perfil....   68999.00
# 43  {'id': 15451254, 'permalink': 'http://perfil.m...     899.00
# 44  {'id': 256324891, 'permalink': 'http://perfil....   82999.00
# 45  {'id': 51553752, 'permalink': 'http://perfil.m...    1989.00
# 46  {'id': 69541508, 'permalink': 'http://perfil.m...   68359.00
# 47  {'id': 243450833, 'permalink': 'http://perfil....  110999.00
# 48  {'id': 85719635, 'permalink': 'http://perfil.m...   12779.10
# 49  {'id': 143125485, 'permalink': 'http://perfil....   76999.00
#
#                                                prices sale_price currency_id  \
# 0   {'id': 'MLA898844422', 'prices': [{'id': '152'...       None         ARS
# 1   {'id': 'MLA926081002', 'prices': [{'id': '45',...       None         ARS
# 2   {'id': 'MLA935211923', 'prices': [{'id': '1', ...       None         ARS
# 3   {'id': 'MLA884683677', 'prices': [{'id': '154'...       None         ARS
# 4   {'id': 'MLA878666563', 'prices': [{'id': '221'...       None         ARS
# 5   {'id': 'MLA921695477', 'prices': [{'id': '11',...       None         ARS
# 6   {'id': 'MLA898843595', 'prices': [{'id': '133'...       None         ARS
# 7   {'id': 'MLA924494260', 'prices': [{'id': '20',...       None         ARS
# 8   {'id': 'MLA935203327', 'prices': [{'id': '1', ...       None         ARS
# 9   {'id': 'MLA921848291', 'prices': [{'id': '33',...       None         ARS
# 10  {'id': 'MLA877436109', 'prices': [{'id': '23',...       None         ARS
# 11  {'id': 'MLA919581387', 'prices': [{'id': '140'...       None         ARS
# 12  {'id': 'MLA919747481', 'prices': [{'id': '90',...       None         ARS
# 13  {'id': 'MLA840417930', 'prices': [{'id': '8', ...       None         ARS
# 14  {'id': 'MLA923198215', 'prices': [{'id': '1', ...       None         ARS
# 15  {'id': 'MLA885495289', 'prices': [{'id': '108'...       None         ARS
# 16  {'id': 'MLA881593414', 'prices': [{'id': '2', ...       None         ARS
# 17  {'id': 'MLA917447444', 'prices': [{'id': '139'...       None         ARS
# 18  {'id': 'MLA921845745', 'prices': [{'id': '16',...       None         ARS
# 19  {'id': 'MLA918449426', 'prices': [{'id': '50',...       None         ARS
# 20  {'id': 'MLA910313990', 'prices': [{'id': '18',...       None         ARS
# 21  {'id': 'MLA854241364', 'prices': [{'id': '23',...       None         ARS
# 22  {'id': 'MLA915986933', 'prices': [{'id': '7', ...       None         ARS
# 23  {'id': 'MLA923246389', 'prices': [{'id': '37',...       None         ARS
# 24  {'id': 'MLA886191424', 'prices': [{'id': '29',...       None         ARS
# 25  {'id': 'MLA885005578', 'prices': [{'id': '60',...       None         ARS
# 26  {'id': 'MLA869878429', 'prices': [{'id': '14',...       None         ARS
# 27  {'id': 'MLA881157553', 'prices': [{'id': '20',...       None         ARS
# 28  {'id': 'MLA921735094', 'prices': [{'id': '11',...       None         ARS
# 29  {'id': 'MLA931108901', 'prices': [{'id': '1', ...       None         ARS
# 30  {'id': 'MLA918036110', 'prices': [{'id': '17',...       None         ARS
# 31  {'id': 'MLA925125866', 'prices': [{'id': '20',...       None         ARS
# 32  {'id': 'MLA929136213', 'prices': [{'id': '6', ...       None         ARS
# 33  {'id': 'MLA920190973', 'prices': [{'id': '8', ...       None         ARS
# 34  {'id': 'MLA928442798', 'prices': [{'id': '1', ...       None         ARS
# 35  {'id': 'MLA919437561', 'prices': [{'id': '6', ...       None         ARS
# 36  {'id': 'MLA920278921', 'prices': [{'id': '17',...       None         ARS
# 37  {'id': 'MLA922859072', 'prices': [{'id': '3', ...       None         ARS
# 38  {'id': 'MLA907653709', 'prices': [{'id': '1', ...       None         ARS
# 39  {'id': 'MLA932556983', 'prices': [{'id': '1', ...       None         ARS
# 40  {'id': 'MLA895899643', 'prices': [{'id': '7', ...       None         ARS
# 41  {'id': 'MLA912582257', 'prices': [{'id': '48',...       None         ARS
# 42  {'id': 'MLA918615346', 'prices': [{'id': '22',...       None         ARS
# 43  {'id': 'MLA798312416', 'prices': [{'id': '14',...       None         ARS
# 44  {'id': 'MLA932728972', 'prices': [{'id': '1', ...       None         ARS
# 45  {'id': 'MLA880314704', 'prices': [{'id': '194'...       None         ARS
# 46  {'id': 'MLA927442698', 'prices': [{'id': '8', ...       None         ARS
# 47  {'id': 'MLA899436143', 'prices': [{'id': '21',...       None         ARS
# 48  {'id': 'MLA854230305', 'prices': [{'id': '23',...       None         ARS
# 49  {'id': 'MLA899857287', 'prices': [{'id': '75',...       None         ARS
#
#     available_quantity  sold_quantity  ... differential_pricing  \
# 0                  169           7505  ...     {'id': 35713319}
# 1                  250            250  ...     {'id': 35713319}
# 2                  350              5  ...     {'id': 35713324}
# 3                  150            500  ...     {'id': 35713319}
# 4                  567           2430  ...     {'id': 35713319}
# 5                  107            231  ...                  NaN
# 6                  427           1529  ...     {'id': 35713319}
# 7                  500            250  ...     {'id': 35713319}
# 8                  238              7  ...                  NaN
# 9                    1            250  ...     {'id': 35713319}
# 10                 161           1873  ...     {'id': 35713319}
# 11                 123            915  ...     {'id': 35713319}
# 12                   1             50  ...                  NaN
# 13                 150            500  ...     {'id': 35713319}
# 14                   4              0  ...     {'id': 35713319}
# 15                 250            500  ...     {'id': 35713319}
# 16                 999             11  ...                  NaN
# 17                 100            200  ...     {'id': 35713319}
# 18                 100            150  ...     {'id': 35713319}
# 19                  50            100  ...     {'id': 35713319}
# 20                 150            250  ...                  NaN
# 21                  48           1012  ...                  NaN
# 22                   1              5  ...                  NaN
# 23                   1            100  ...                  NaN
# 24                  19            200  ...                  NaN
# 25                   1             50  ...     {'id': 35713319}
# 26                  48             22  ...                  NaN
# 27                   3            284  ...                  NaN
# 28                   1             25  ...                  NaN
# 29                   1              5  ...                  NaN
# 30                 150            100  ...     {'id': 35713319}
# 31                 100             25  ...     {'id': 35713319}
# 32                   1              5  ...                  NaN
# 33                 100            100  ...     {'id': 35713319}
# 34                  50             25  ...     {'id': 35713319}
# 35                  96             31  ...                  NaN
# 36                   3             13  ...                  NaN
# 37                   1              5  ...                  NaN
# 38                   1              0  ...                  NaN
# 39                  50              5  ...     {'id': 35713319}
# 40                   4             14  ...                  NaN
# 41                   1            200  ...                  NaN
# 42                   1              5  ...     {'id': 35713319}
# 43                 100            500  ...                  NaN
# 44                   1             50  ...     {'id': 35713319}
# 45                   1            200  ...                  NaN
# 46                   1              5  ...                  NaN
# 47                   1             25  ...                  NaN
# 48                   1            500  ...                  NaN
# 49                 107             13  ...                  NaN
#
#    original_price category_id official_store_id  \
# 0             NaN     MLA1002            1938.0
# 1             NaN     MLA1002            1938.0
# 2             NaN     MLA1002            1938.0
# 3             NaN     MLA1002            1938.0
# 4             NaN     MLA1002            1938.0
# 5             NaN   MLA352001               NaN
# 6             NaN     MLA1002            1938.0
# 7        66999.00     MLA1002            1372.0
# 8             NaN     MLA1002            1938.0
# 9             NaN     MLA1002            1192.0
# 10       59999.00     MLA1002            1824.0
# 11            NaN     MLA1002            1938.0
# 12       56999.05     MLA1002               NaN
# 13       59999.00     MLA1002            1824.0
# 14      124999.00     MLA1002               NaN
# 15            NaN     MLA1002            1938.0
# 16            NaN   MLA352001               NaN
# 17            NaN     MLA1002            1938.0
# 18       81999.00     MLA1002            1192.0
# 19            NaN     MLA1002            1372.0
# 20            NaN   MLA352001               NaN
# 21       14199.00   MLA352001               NaN
# 22            NaN     MLA1002            1256.0
# 23      136899.00     MLA1002               NaN
# 24            NaN     MLA1002             229.0
# 25            NaN     MLA1002               NaN
# 26            NaN     MLA1002            2227.0
# 27       11549.00   MLA352001               NaN
# 28            NaN     MLA1002               NaN
# 29            NaN     MLA1002               NaN
# 30            NaN     MLA1002              56.0
# 31       82999.00     MLA1002            1192.0
# 32            NaN     MLA1002               NaN
# 33            NaN     MLA1002             229.0
# 34       77999.00     MLA1002            1372.0
# 35            NaN     MLA1002            1255.0
# 36            NaN     MLA1002               NaN
# 37            NaN     MLA1002               NaN
# 38            NaN     MLA1002             251.0
# 39       83049.00     MLA1002            1372.0
# 40            NaN     MLA1002               NaN
# 41            NaN   MLA352001               NaN
# 42            NaN     MLA1002              56.0
# 43            NaN    MLA49334               NaN
# 44            NaN     MLA1002            1229.0
# 45            NaN   MLA431802               NaN
# 46            NaN     MLA1002               NaN
# 47            NaN     MLA1002               NaN
# 48       14199.00   MLA352001               NaN
# 49            NaN     MLA1002             229.0
#
#                                   domain_id catalog_product_id  \
# 0                           MLA-TELEVISIONS        MLA16233171
# 1                           MLA-TELEVISIONS               None
# 2                           MLA-TELEVISIONS        MLA17849007
# 3                           MLA-TELEVISIONS        MLA16233171
# 4                           MLA-TELEVISIONS        MLA15699007
# 5               MLA-STREAMING_MEDIA_DEVICES        MLA16233185
# 6                           MLA-TELEVISIONS        MLA16234225
# 7                           MLA-TELEVISIONS               None
# 8                           MLA-TELEVISIONS        MLA18360187
# 9                           MLA-TELEVISIONS               None
# 10                          MLA-TELEVISIONS        MLA15998081
# 11                          MLA-TELEVISIONS        MLA16202534
# 12                          MLA-TELEVISIONS               None
# 13                          MLA-TELEVISIONS        MLA15998081
# 14                          MLA-TELEVISIONS        MLA17325852
# 15                          MLA-TELEVISIONS        MLA16234225
# 16              MLA-STREAMING_MEDIA_DEVICES        MLA14141341
# 17                          MLA-TELEVISIONS        MLA16202534
# 18                          MLA-TELEVISIONS               None
# 19                          MLA-TELEVISIONS               None
# 20              MLA-STREAMING_MEDIA_DEVICES        MLA16233184
# 21              MLA-STREAMING_MEDIA_DEVICES        MLA13877783
# 22                          MLA-TELEVISIONS        MLA17546860
# 23                          MLA-TELEVISIONS               None
# 24                          MLA-TELEVISIONS        MLA16119781
# 25                          MLA-TELEVISIONS        MLA16233171
# 26                          MLA-TELEVISIONS         MLA8060008
# 27              MLA-STREAMING_MEDIA_DEVICES        MLA15543405
# 28                          MLA-TELEVISIONS               None
# 29                          MLA-TELEVISIONS               None
# 30                          MLA-TELEVISIONS               None
# 31                          MLA-TELEVISIONS        MLA17546860
# 32                          MLA-TELEVISIONS               None
# 33                          MLA-TELEVISIONS               None
# 34                          MLA-TELEVISIONS        MLA18360021
# 35                          MLA-TELEVISIONS        MLA15963128
# 36                          MLA-TELEVISIONS        MLA11008595
# 37                          MLA-TELEVISIONS        MLA15699007
# 38                          MLA-TELEVISIONS        MLA15581928
# 39                          MLA-TELEVISIONS        MLA18352770
# 40                          MLA-TELEVISIONS        MLA16009125
# 41              MLA-STREAMING_MEDIA_DEVICES        MLA14141340
# 42                          MLA-TELEVISIONS               None
# 43                   MLA-TV_REMOTE_CONTROLS               None
# 44                          MLA-TELEVISIONS               None
# 45  MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS               None
# 46                          MLA-TELEVISIONS               None
# 47                          MLA-TELEVISIONS        MLA17325852
# 48              MLA-STREAMING_MEDIA_DEVICES        MLA13877782
# 49                          MLA-TELEVISIONS        MLA15835122
#
#                                                  tags  catalog_listing  \
# 0   [extended_warranty_eligible, good_quality_pict...             True
# 1   [ahora-12, catalog_product_candidate, extended...              NaN
# 2   [ahora-24, extended_warranty_eligible, good_qu...             True
# 3   [loyalty_discount_eligible, ahora-12, brand_ve...              NaN
# 4   [good_quality_picture, good_quality_thumbnail,...             True
# 5   [good_quality_picture, good_quality_thumbnail,...             True
# 6   [loyalty_discount_eligible, ahora-12, brand_ve...             True
# 7   [extended_warranty_eligible, good_quality_pict...              NaN
# 8   [extended_warranty_eligible, good_quality_pict...             True
# 9   [ahora-12, catalog_product_candidate, extended...              NaN
# 10  [loyalty_discount_eligible, ahora-12, brand_ve...             True
# 11  [good_quality_thumbnail, ahora-12, extended_wa...             True
# 12  [catalog_product_candidate, extended_warranty_...              NaN
# 13  [ahora-12, brand_verified, good_quality_pictur...              NaN
# 14  [ahora-12, extended_warranty_eligible, good_qu...             True
# 15  [ahora-12, brand_verified, extended_warranty_e...              NaN
# 16  [brand_verified, good_quality_picture, good_qu...             True
# 17  [ahora-12, extended_warranty_eligible, good_qu...              NaN
# 18  [ahora-12, catalog_product_candidate, extended...              NaN
# 19  [extended_warranty_eligible, good_quality_pict...              NaN
# 20  [good_quality_picture, good_quality_thumbnail,...              NaN
# 21  [loyalty_discount_eligible, brand_verified, go...             True
# 22  [catalog_product_candidate, extended_warranty_...              NaN
# 23  [good_quality_thumbnail, catalog_product_candi...              NaN
# 24  [good_quality_picture, brand_verified, extende...             True
# 25  [ahora-12, brand_verified, extended_warranty_e...              NaN
# 26  [brand_verified, extended_warranty_eligible, g...             True
# 27  [brand_verified, good_quality_picture, good_qu...             True
# 28  [good_quality_thumbnail, loyalty_discount_elig...              NaN
# 29  [catalog_product_candidate, extended_warranty_...              NaN
# 30  [good_quality_thumbnail, loyalty_discount_elig...              NaN
# 31  [catalog_product_candidate, extended_warranty_...              NaN
# 32  [good_quality_picture, good_quality_thumbnail,...              NaN
# 33  [extended_warranty_eligible, good_quality_pict...              NaN
# 34  [ahora-12, extended_warranty_eligible, good_qu...              NaN
# 35  [extended_warranty_eligible, good_quality_pict...             True
# 36  [extended_warranty_eligible, good_quality_pict...             True
# 37  [extended_warranty_eligible, good_quality_pict...              NaN
# 38  [extended_warranty_eligible, good_quality_pict...             True
# 39  [ahora-12, catalog_product_candidate, extended...              NaN
# 40  [extended_warranty_eligible, good_quality_pict...             True
# 41  [good_quality_picture, good_quality_thumbnail,...              NaN
# 42  [extended_warranty_eligible, good_quality_pict...              NaN
# 43  [good_quality_picture, good_quality_thumbnail,...              NaN
# 44  [ahora-12, catalog_product_candidate, extended...              NaN
# 45  [loyalty_discount_eligible, brand_verified, go...              NaN
# 46  [good_quality_picture, good_quality_thumbnail,...              NaN
# 47  [loyalty_discount_eligible, extended_warranty_...              NaN
# 48  [brand_verified, good_quality_picture, good_qu...              NaN
# 49  [brand_verified, extended_warranty_eligible, g...             True
#
#    use_thumbnail_id order_backend
# 0              True             1
# 1              True             2
# 2              True             3
# 3              True             4
# 4              True             5
# 5              True             6
# 6              True             7
# 7              True             8
# 8              True             9
# 9              True            10
# 10             True            11
# 11             True            12
# 12             True            13
# 13             True            14
# 14             True            15
# 15             True            16
# 16             True            17
# 17             True            18
# 18             True            19
# 19             True            20
# 20            False            21
# 21             True            22
# 22             True            23
# 23            False            24
# 24             True            25
# 25             True            26
# 26             True            27
# 27             True            28
# 28             True            29
# 29             True            30
# 30             True            31
# 31             True            32
# 32             True            33
# 33             True            34
# 34             True            35
# 35             True            36
# 36             True            37
# 37             True            38
# 38             True            39
# 39             True            40
# 40             True            41
# 41            False            42
# 42             True            43
# 43             True            44
# 44             True            45
# 45             True            46
# 46             True            47
# 47             True            48
# 48            False            49
# 49             True            50
#
# [50 rows x 33 columns]

# %%
# conozco las columnas que posee
df1.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price',
#        'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode',
#        'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail',
#        'thumbnail_id', 'accepts_mercadopago', 'installments', 'address',
#        'shipping', 'seller_address', 'attributes', 'differential_pricing',
#        'original_price', 'category_id', 'official_store_id', 'domain_id',
#        'catalog_product_id', 'tags', 'catalog_listing', 'use_thumbnail_id',
#        'order_backend'],
#       dtype='object')

# %% [markdown]
# Para una instancia a futuro algunos de los campos más interesantes son:
# * *installments* > *adress*
# * *seller* > *seller_reputation* > *transactions*
# * *tag* => se puede aplicar text mining para determinar como inlfuye en las ventas de la publicacion

# %%
# suando incluso el código de ID_USER, no se obteiene el resultado esperado
ID_USER = input("Ingrese su ID_USER otorgado por Mercado Libre") 
url = 'https://api.mercadolibre.com/users/$' +str('ID_USER') + '/MLA/search?search_type=scan'
result3 = requests.get(url)
data3 = result3.json()
data3
# Out:
# Ingrese su ID_USER otorgado por Mercado Libre8687674606437847
# {'error': 'resource not found',
#  'message': 'Si quieres conocer los recursos de la API que se encuentran disponibles visita el Sitio de Desarrolladores de MercadoLibre (http://developers.mercadolibre.com)'}

# %% [markdown]
#  <a id="1.3"></a>
# #### 1.3) Armando el Dataset
# En esta instancia continuaré con el proceso de extracción de datos para armar el dataset

# %% [markdown]
# Mediante la definicion de una funcion voy realizar las consultas a la API de MELI cada 15 seg, obteniendo 1000 resultados por busqueda.
#
# En esta instancia, focalizare en ciertos elementos de electronica como tv, celulares, notebooks, tablets (elementos que más destaquen en las búsquedas o con una gran cantidad de publicaciones)

# %%
# voy a definir una función para realizar las consultas, y tomar el resultado y entregarlo como un dataset
def call_data(vector = [0,50], url = 'https://api.mercadolibre.com/sites/MLA/search?q=tv%204k' ):
    '''Funcion para llamar a la API de mercado libre con un resultado especifico, haciendo consultas de 50 en 50
    y guardandolas en un data frame'''
    t = len(vector)
    lista1 = [] #instancio una lista vacia
    for t in list(range( 0,len(vector),1 ) ):
        url_act = url + '&offset=' + str( vector[t] )
        #print(url_act) #para comprobar la direccion
        result = requests.get(url_act)
        if result2.status_code == 200:
            #lista2 = result.json()['results']
            lista1.extend( result.json()['results'] )
        else:
            print('hubo un error')
            df_rta = pd.DataFrame(lista1)  
        print(t, end="\r")
        sleep(15) #cada 15 segundos
        
    df_rta = pd.DataFrame(lista1)    
    return df_rta

# %%
df_tv = call_data(
    vector = list( range(0, 1001, 50) ),
    url = 'https://api.mercadolibre.com/sites/MLA/search?q=tv%204k')
# Out:
# 20

# %%
#veamos las dimensiones del data set
df_tv.shape
# Out:
# (1047, 33)

# %%
df_tv.to_csv('./data/data_tv_4k_1krows.csv', index= False)

# %%
df_tv.head()
# Out:
#              id site_id                                              title  \
# 0  MLA898844422     MLA  Smart Tv Samsung Series 7 Un50tu7000gczb Led 4...
# 1  MLA926081002     MLA                    Smart Tv Bgh 50 4k  Uhd Android
# 2  MLA935211923     MLA         Smart Tv Hyundai Hyled-50uhd5a 4k 50  220v
# 3  MLA884683677     MLA                Smart Tv Samsung 50 4k Uhd 50tu7000
# 4  MLA878666563     MLA  Smart Tv Philips 6600 Series 50pud6654/77 Led ...
#
#                                               seller    price  \
# 0  {'id': 608846165, 'permalink': 'http://perfil....  75999.0
# 1  {'id': 608846165, 'permalink': 'http://perfil....  62999.0
# 2  {'id': 608846165, 'permalink': 'http://perfil....  69999.0
# 3  {'id': 608846165, 'permalink': 'http://perfil....  75999.0
# 4  {'id': 608846165, 'permalink': 'http://perfil....  62999.0
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLA898844422', 'prices': [{'id': '152'...       None         ARS
# 1  {'id': 'MLA926081002', 'prices': [{'id': '45',...       None         ARS
# 2  {'id': 'MLA935211923', 'prices': [{'id': '1', ...       None         ARS
# 3  {'id': 'MLA884683677', 'prices': [{'id': '154'...       None         ARS
# 4  {'id': 'MLA878666563', 'prices': [{'id': '221'...       None         ARS
#
#    available_quantity  sold_quantity  ... differential_pricing original_price  \
# 0                 169           7505  ...     {'id': 35713319}            NaN
# 1                 250            250  ...     {'id': 35713319}            NaN
# 2                 350              5  ...     {'id': 35713324}            NaN
# 3                 150            500  ...     {'id': 35713319}            NaN
# 4                 567           2430  ...     {'id': 35713319}            NaN
#
#   category_id official_store_id        domain_id catalog_product_id  \
# 0     MLA1002            1938.0  MLA-TELEVISIONS        MLA16233171
# 1     MLA1002            1938.0  MLA-TELEVISIONS               None
# 2     MLA1002            1938.0  MLA-TELEVISIONS        MLA17849007
# 3     MLA1002            1938.0  MLA-TELEVISIONS        MLA16233171
# 4     MLA1002            1938.0  MLA-TELEVISIONS        MLA15699007
#
#                                                 tags  catalog_listing  \
# 0  [extended_warranty_eligible, good_quality_pict...             True
# 1  [catalog_product_candidate, extended_warranty_...              NaN
# 2  [ahora-24, extended_warranty_eligible, good_qu...             True
# 3  [loyalty_discount_eligible, ahora-12, brand_ve...              NaN
# 4  [good_quality_picture, good_quality_thumbnail,...             True
#
#   use_thumbnail_id order_backend
# 0             True             1
# 1             True             2
# 2             True             3
# 3             True             4
# 4             True             5
#
# [5 rows x 33 columns]

# %%
df_cel = call_data(
    vector = list( range(0, 1001, 50) ),
    url = 'https://api.mercadolibre.com/sites/MLA/search?q=celular%20')

#df_cel.to_excel('./data/data_celular_1krows.xlsx', index= False)
df_cel.to_csv('./data/data_celular_1krows.csv', index= False)
# Out:
# 20

# %%
df_tab = call_data(
    vector = list( range(0, 1001, 50) ),
    url = 'https://api.mercadolibre.com/sites/MLA/search?q=tablet%20')

df_tab.to_csv('./data/data_tablet_1krows.csv', index= False)
# Out:
# 20

# %%
df_notebook = call_data(
    vector = list( range(0, 1001, 50) ),
    url = 'https://api.mercadolibre.com/sites/MLA/search?q=notebook%20')

df_notebook.to_csv('./data/data_notebook_1krows.csv', index= False)
# Out:
# 20

# %%
## solo en el caso de querer leer los archivos desde csv
#df_tv = pd.read_excel('./data/data_tv_4k_1krows.xlsx')
#df_cel = pd.read_excel('./data/data_celular_1krows.xlsx')
#df_notebook = pd.read_excel('./data/data_notebook_1krows.xlsx')
#df_tab = pd.read_excel('./data/data_tablet_1krows.xlsx')

#df_tv = pd.read_csv('./data/data_tv_4k_1krows.csv')
#df_cel = pd.read_csv('./data/data_celular_1krows.csv')
#df_notebook = pd.read_csv('./data/data_notebook_1krows.csv')
#df_tab = pd.read_csv('./data/data_tablet_1krows.csv')

# %% [markdown]
# Concatenamos los dataframes obtenidos hasta el momento como uno solo, concatenando uno detras del otro.

# %%
# concatenamos los datasets obtenidos hasta el momento
df = pd.concat([df_tv, df_cel, df_tab, df_notebook], axis = 0).reset_index(drop = True)

# %%
df
# Out:
#                 id site_id                                              title  \
# 0     MLA898844422     MLA  Smart Tv Samsung Series 7 Un50tu7000gczb Led 4...
# 1     MLA926081002     MLA                    Smart Tv Bgh 50 4k  Uhd Android
# 2     MLA935211923     MLA         Smart Tv Hyundai Hyled-50uhd5a 4k 50  220v
# 3     MLA884683677     MLA                Smart Tv Samsung 50 4k Uhd 50tu7000
# 4     MLA878666563     MLA  Smart Tv Philips 6600 Series 50pud6654/77 Led ...
# ...            ...     ...                                                ...
# 4160  MLA865478239     MLA  Notebook Bangho Intel Core I5 15,6 Hd 8gb Ssd ...
# 4161  MLA901539489     MLA  Notebook Bangho Max L5 I3 240gb 8gb Ram 15.6 C...
# 4162  MLA910513713     MLA  Notebook Bangho Dual Core 4gb 480gb Ssd Win10 ...
# 4163  MLA909819728     MLA  Notebook Lenovo Thinkpad L15 I5 10210u 8gb Ssd...
# 4164  MLA928151151     MLA  Notebook Hp 14-dk1016la Amd 3050u 4gb 256gb Wi...
#
#                                                  seller     price  \
# 0     {'id': 608846165, 'permalink': 'http://perfil....   75999.0
# 1     {'id': 608846165, 'permalink': 'http://perfil....   62999.0
# 2     {'id': 608846165, 'permalink': 'http://perfil....   69999.0
# 3     {'id': 608846165, 'permalink': 'http://perfil....   75999.0
# 4     {'id': 608846165, 'permalink': 'http://perfil....   62999.0
# ...                                                 ...       ...
# 4160  {'id': 31875925, 'permalink': 'http://perfil.m...   90999.0
# 4161  {'id': 155107410, 'permalink': 'http://perfil....   94900.0
# 4162  {'id': 31875925, 'permalink': 'http://perfil.m...   74999.0
# 4163  {'id': 131648529, 'permalink': 'http://perfil....  129995.0
# 4164  {'id': 9877009, 'permalink': 'http://perfil.me...   66189.9
#
#                                                  prices sale_price  \
# 0     {'id': 'MLA898844422', 'prices': [{'id': '152'...       None
# 1     {'id': 'MLA926081002', 'prices': [{'id': '45',...       None
# 2     {'id': 'MLA935211923', 'prices': [{'id': '1', ...       None
# 3     {'id': 'MLA884683677', 'prices': [{'id': '154'...       None
# 4     {'id': 'MLA878666563', 'prices': [{'id': '221'...       None
# ...                                                 ...        ...
# 4160  {'id': 'MLA865478239', 'prices': [{'id': '8', ...       None
# 4161  {'id': 'MLA901539489', 'prices': [{'id': '4', ...       None
# 4162  {'id': 'MLA910513713', 'prices': [{'id': '20',...       None
# 4163  {'id': 'MLA909819728', 'prices': [{'id': '1', ...       None
# 4164  {'id': 'MLA928151151', 'prices': [{'id': '2', ...       None
#
#      currency_id  available_quantity  sold_quantity  ... differential_pricing  \
# 0            ARS                 169           7505  ...     {'id': 35713319}
# 1            ARS                 250            250  ...     {'id': 35713319}
# 2            ARS                 350              5  ...     {'id': 35713324}
# 3            ARS                 150            500  ...     {'id': 35713319}
# 4            ARS                 567           2430  ...     {'id': 35713319}
# ...          ...                 ...            ...  ...                  ...
# 4160         ARS                5000              5  ...                  NaN
# 4161         ARS                   1              4  ...     {'id': 35713297}
# 4162         ARS                5000              5  ...     {'id': 35713297}
# 4163         ARS                   1              5  ...                  NaN
# 4164         ARS                   1              1  ...                  NaN
#
#      original_price category_id official_store_id        domain_id  \
# 0               NaN     MLA1002            1938.0  MLA-TELEVISIONS
# 1               NaN     MLA1002            1938.0  MLA-TELEVISIONS
# 2               NaN     MLA1002            1938.0  MLA-TELEVISIONS
# 3               NaN     MLA1002            1938.0  MLA-TELEVISIONS
# 4               NaN     MLA1002            1938.0  MLA-TELEVISIONS
# ...             ...         ...               ...              ...
# 4160            NaN     MLA1652               NaN    MLA-NOTEBOOKS
# 4161            NaN     MLA1652               NaN    MLA-NOTEBOOKS
# 4162            NaN     MLA1652               NaN    MLA-NOTEBOOKS
# 4163            NaN     MLA1652               NaN    MLA-NOTEBOOKS
# 4164            NaN     MLA1652               NaN    MLA-NOTEBOOKS
#
#      catalog_product_id                                               tags  \
# 0           MLA16233171  [extended_warranty_eligible, good_quality_pict...
# 1                  None  [catalog_product_candidate, extended_warranty_...
# 2           MLA17849007  [ahora-24, extended_warranty_eligible, good_qu...
# 3           MLA16233171  [loyalty_discount_eligible, ahora-12, brand_ve...
# 4           MLA15699007  [good_quality_picture, good_quality_thumbnail,...
# ...                 ...                                                ...
# 4160        MLA16029705  [loyalty_discount_eligible, brand_verified, ca...
# 4161        MLA17512115  [good_quality_thumbnail, loyalty_discount_elig...
# 4162        MLA16189142  [ahora-12, catalog_listing_eligible, extended_...
# 4163               None  [loyalty_discount_eligible, extended_warranty_...
# 4164               None  [extended_warranty_eligible, good_quality_pict...
#
#       catalog_listing use_thumbnail_id order_backend
# 0                True             True             1
# 1                 NaN             True             2
# 2                True             True             3
# 3                 NaN             True             4
# 4                True             True             5
# ...               ...              ...           ...
# 4160              NaN            False            46
# 4161              NaN            False            47
# 4162              NaN            False            48
# 4163              NaN            False            49
# 4164              NaN            False            50
#
# [4165 rows x 33 columns]

# %% [markdown]
# <a id="1.4"></a>
# #### 1.4) Analisis del dataset

# %%
df.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price',
#        'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode',
#        'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail',
#        'thumbnail_id', 'accepts_mercadopago', 'installments', 'address',
#        'shipping', 'seller_address', 'attributes', 'differential_pricing',
#        'original_price', 'category_id', 'official_store_id', 'domain_id',
#        'catalog_product_id', 'tags', 'catalog_listing', 'use_thumbnail_id',
#        'order_backend'],
#       dtype='object')

# %% [markdown]
# Al provenir transformar una lista de diccionario, que originalmente venía de una consulta tipo json, me encuentro con que algunas columnas contienen su información en formato dic. Vamos a explorarla, y de paso, ver que información se puede obtener sin tener que aplicar text mining en esta instancia

# %%
# exploro la cantidad de nulos y tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4165 entries, 0 to 4164
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4165 non-null   object
#  1   site_id               4165 non-null   object
#  2   title                 4165 non-null   object
#  3   seller                4165 non-null   object
#  4   price                 4165 non-null   float64
#  5   prices                4165 non-null   object
#  6   sale_price            0 non-null      object
#  7   currency_id           4165 non-null   object
#  8   available_quantity    4165 non-null   int64
#  9   sold_quantity         4165 non-null   int64
#  10  buying_mode           4165 non-null   object
#  11  listing_type_id       4165 non-null   object
#  12  stop_time             4165 non-null   object
#  13  condition             4165 non-null   object
#  14  permalink             4165 non-null   object
#  15  thumbnail             4165 non-null   object
#  16  thumbnail_id          4164 non-null   object
#  17  accepts_mercadopago   4165 non-null   bool
#  18  installments          4159 non-null   object
#  19  address               4165 non-null   object
#  20  shipping              4165 non-null   object
#  21  seller_address        4165 non-null   object
#  22  attributes            4165 non-null   object
#  23  differential_pricing  1304 non-null   object
#  24  original_price        545 non-null    float64
#  25  category_id           4165 non-null   object
#  26  official_store_id     669 non-null    float64
#  27  domain_id             4165 non-null   object
#  28  catalog_product_id    3067 non-null   object
#  29  tags                  4165 non-null   object
#  30  catalog_listing       444 non-null    object
#  31  use_thumbnail_id      4165 non-null   bool
#  32  order_backend         4165 non-null   int64
# dtypes: bool(2), float64(3), int64(3), object(25)
# memory usage: 1017.0+ KB

# %%
# 
df.describe()
# Out:
#               price  available_quantity  sold_quantity  original_price  \
# count  4.165000e+03         4165.000000    4165.000000      545.000000
# mean   7.543591e+04          137.558223      45.366387    71934.556147
# std    3.693016e+05         1451.521984     269.747362    60110.166556
# min    3.300000e+01            1.000000       0.000000     1599.990000
# 25%    1.600000e+04            1.000000       1.000000    19999.000000
# 50%    5.297900e+04            1.000000       5.000000    61590.000000
# 75%    9.597500e+04            5.000000      25.000000   109999.000000
# max    2.335000e+07        50000.000000   11030.000000   334999.000000
#
#        official_store_id  order_backend
# count         669.000000    4165.000000
# mean          962.116592      25.485954
# std           817.399770      14.426887
# min            47.000000       1.000000
# 25%           229.000000      13.000000
# 50%           945.000000      25.000000
# 75%          1550.000000      38.000000
# max          2549.000000      50.000000

# %% [markdown]
# Para este caso, cabe resaltar que *id, order_backend, official_store_id* si bien son numericos no aportan explicaciones al analisis de datos.
# En cuanto al resto de las variables, como *price, available_quantity, sold_quantity, original_price* se veran influenciadas por los tipos de productos, y a su vez por las carateristicas del mismo

# %%
# tipos de dominios, para identificar si la busqueda me devolvio efectivamente los cambos de las busquedas
df.domain_id.value_counts()
# Out:
# MLA-NOTEBOOKS                                 1050
# MLA-TABLETS                                   1043
# MLA-CELLPHONES                                1025
# MLA-TELEVISIONS                                856
# MLA-STREAMING_MEDIA_DEVICES                     85
# MLA-TV_REMOTE_CONTROLS                          51
# MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS         38
# MLA-TV_AND_MONITOR_MOUNTS                       10
# MLA-ELECTRONIC_ACCESSORIES_AND_SPARE_PARTS       3
# MLA-ELECTRONIC_PRODUCTS                          1
# MLA-TV_REMOTE_CONTROL_COVERS                     1
# MLA-TV_RECEIVERS_AND_DECODERS                    1
# MLA-STREAMING_MEDIA_PLAYER_REMOTE_CONTROLS       1
# Name: domain_id, dtype: int64

# %% [markdown]
# <a id="1.4.1"></a>
# #### 1.4.1) Visualizacion de datos

# %%
sns.countplot(x='domain_id', data=df,orient = 'v', order=df['domain_id'].value_counts().index)
plt.xticks(rotation=90);
#plt.tight_layout()

# %%
(df.groupby('domain_id')['price'].agg(['mean','median','std','max','min']).round(2)).sort_values(by = 'mean', ascending=False)
# Out:
#                                                  mean    median        std  \
# domain_id
# MLA-NOTEBOOKS                               119090.01  109705.7   57819.44
# MLA-TELEVISIONS                             110556.51   78104.5  112460.26
# MLA-TABLETS                                  56100.81   16999.0  724048.61
# MLA-CELLPHONES                               34007.11   24399.0   33930.13
# MLA-STREAMING_MEDIA_PLAYER_REMOTE_CONTROLS   17999.00   17999.0        NaN
# MLA-STREAMING_MEDIA_DEVICES                  11232.18   10399.0    7774.38
# MLA-TV_RECEIVERS_AND_DECODERS                 8960.00    8960.0        NaN
# MLA-ELECTRONIC_ACCESSORIES_AND_SPARE_PARTS    8122.70    7499.0    1533.81
# MLA-ELECTRONIC_PRODUCTS                       5370.00    5370.0        NaN
# MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS       1654.77    1501.5    1107.49
# MLA-TV_REMOTE_CONTROL_COVERS                  1600.00    1600.0        NaN
# MLA-TV_AND_MONITOR_MOUNTS                     1596.15     524.5    2074.78
# MLA-TV_REMOTE_CONTROLS                         928.62     798.0     889.81
#
#                                                     max       min
# domain_id
# MLA-NOTEBOOKS                                 602539.50    500.00
# MLA-TELEVISIONS                              1240000.00     33.00
# MLA-TABLETS                                 23350000.00     65.00
# MLA-CELLPHONES                                313646.00     50.00
# MLA-STREAMING_MEDIA_PLAYER_REMOTE_CONTROLS     17999.00  17999.00
# MLA-STREAMING_MEDIA_DEVICES                    64999.00   5499.00
# MLA-TV_RECEIVERS_AND_DECODERS                   8960.00   8960.00
# MLA-ELECTRONIC_ACCESSORIES_AND_SPARE_PARTS      9870.11   6999.00
# MLA-ELECTRONIC_PRODUCTS                         5370.00   5370.00
# MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS         3990.00    199.91
# MLA-TV_REMOTE_CONTROL_COVERS                    1600.00   1600.00
# MLA-TV_AND_MONITOR_MOUNTS                       6999.99    299.99
# MLA-TV_REMOTE_CONTROLS                          6990.00    550.00

# %% [markdown]
# Las notebooks representan aquellos productos que tienen el mayor precio promedio (independientemente de la gama del articulo)
# En tanto que los celulares tienen el menor precio medio.
# La diferencia entre la media y la mediana en estos casos se debe, ademas de la presencia de outliers en los datos, dependera de las carateristicas y la cantidad de productos para las distintas gamas.
#
# Tambien podemos ver que los maximos hay valores hasta 2 ordenedes de magnitud por encima del orden de la media y la mediana. En el caso de Tablets por ejemplo, la media y mediana estan en el orden de 1e4, en tanto que el maximo valor esta en el orden de 1e7; otro sucede con los televisores.
#
#
# Aquellos que tienen std = NaN, son aquellos elementos que son unicos, ya que temino dividinedo por 0 (n-1).
# Estos son productos que se colaron el la busqueda de television, donde los resultados entregados no fueron tan precisos como con tablets, notebooks y celulares.
#
# domain_id = ['MLA-ELECTRONIC_ACCESSORIES_AND_SPARE_PARTS', 'MLA-TV_RECEIVERS_AND_DECODERS', 'MLA-TV_REMOTE_CONTROL_COVERS']

# %%
plt.figure(figsize = (16, 4))

ax = plt.subplot(1,2,1)
data_2plot = df[df['domain_id'] == 'MLA-TELEVISIONS']
plt.hist(data=data_2plot, x='price', bins=50)
plt.title('Histograma Televisores 4K')

ax = plt.subplot(1,2,2)
sns.violinplot(data=data_2plot, x='price', bins=10)
plt.title('Violinplot Televisores 4K')
plt.show()

# %%
plt.figure(figsize = (16, 4))
ax = plt.subplot(1,2,1)
data_2plot = df[df['domain_id'] == 'MLA-CELLPHONES']
plt.hist(data=data_2plot, x='price', bins=50, color= 'green')
plt.title('Histograma Celulares 4K')

ax = plt.subplot(1,2,2)
sns.violinplot(data=data_2plot, x='price', bins=10, color= 'green')
plt.title('Violinplot Celulares 4K')
plt.show()

# %%
plt.figure(figsize = (16, 4))
ax = plt.subplot(1,2,1)
data_2plot = df[df['domain_id'] == 'MLA-TABLETS']
plt.hist(data=data_2plot, x='price', bins=50, color= 'red')
plt.title('Histograma Tables')

ax = plt.subplot(1,2,2)
sns.violinplot(data=data_2plot, x='price', bins=50, color= 'red')
plt.title('Violinplot Tablets')
plt.show()

# %%
plt.figure(figsize = (16, 4))
ax = plt.subplot(1,2,1)
data_2plot = df[df['domain_id'] == 'MLA-NOTEBOOKS']
plt.hist(data=data_2plot, x='price', bins=50, color= 'purple')
plt.title('Histograma Notebooks')

ax = plt.subplot(1,2,2)
sns.violinplot(data=data_2plot, x='price', bins=50, color= 'purple')
plt.title('Violinplot Notebooks')
plt.show()

# %%
(df.groupby('domain_id')['sold_quantity'].agg(['mean','median','std','max','min']).round(2)).\
                        sort_values(by = 'mean', ascending=False)
# Out:
#                                               mean  median     std    max  min
# domain_id
# MLA-ELECTRONIC_ACCESSORIES_AND_SPARE_PARTS  185.00      50  273.72    500    5
# MLA-STREAMING_MEDIA_DEVICES                 173.04      50  534.53   4818    0
# MLA-TV_REMOTE_CONTROLS                       77.10      25  121.94    500    2
# MLA-CELLPHONES                               67.39       5  246.05   5455    0
# MLA-TV_AND_MONITOR_MOUNTS                    61.60      25   88.74    250    3
# MLA-AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS      58.26       5  111.54    500    1
# MLA-TV_REMOTE_CONTROL_COVERS                 50.00      50     NaN     50   50
# MLA-TABLETS                                  42.76       2  362.41  11030    0
# MLA-NOTEBOOKS                                30.43       5   77.52    745    0
# MLA-ELECTRONIC_PRODUCTS                      25.00      25     NaN     25   25
# MLA-TELEVISIONS                              24.79       0  285.73   7505    0
# MLA-STREAMING_MEDIA_PLAYER_REMOTE_CONTROLS    5.00       5     NaN      5    5
# MLA-TV_RECEIVERS_AND_DECODERS                 5.00       5     NaN      5    5

# %% [markdown]
# En cuanto a las unidades vendidas por categorías se puede apreciar que la media ronda el mismo orden para los distintos productos.
# Sin embargo puede llegar a ser muy dispar las ventas que se producen para las distintas publicaciones y vendedores, nos podemos dar cuenta de ello debido a las medianas cuando son muy pequeñas respecto de su media, y el maximo es bastante mayor.

# %% [markdown]
# <a id="1.4.2"></a>
# #### 1.4.2) Estudio de correlaciones

# %%
# graficamos un heatmap para exploras la relacion entre variables
plt.figure(figsize=(12,6))
# para no incorporar solamente aquellas variables numericas, ya que de lo contrario me tomaria los buleanos 
num_cols = [x for x in df.select_dtypes(include=['number']).columns]
sns.heatmap(df[num_cols].corr(),annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# De los valores numericos, ignorando *id, order_backend, official_store_id* hay una fuerte corelacion entre price y original_price, y no es 1 directamente debido a que existen descuento aplicado, de lo contrario seria null en este caso.

# %% [markdown]
# <a id="1.4.3"></a>
# #### 1.4.3) Respoindiendo algunas preguntas de negocios
# Veamos cuantos productos tienen descuentos en esta muestra:

# %%
(df.original_price.isnull()).value_counts()
# Out:
# True     3620
# False     545
# Name: original_price, dtype: int64

# %%
# cuantos productos generales tienen descuento, y que % representa del total
print("La cantidad de productos con descuento es {}, y representa el {} % del total de productos de las busquedas".format(
        (df.original_price.isnull()).value_counts()[0] ,
        round(((df.original_price.isnull()).value_counts()[0] / len(df))*100, 2)
        )
     )
# Out:
# La cantidad de productos con descuento es 545, y representa el 13.09 % del total de productos de las busquedas

# %%
categoria_productos = {'televisores':'MLA-TELEVISIONS','celulares':'MLA-CELLPHONES','tablets':'MLA-TABLETS',\
                       'notebooks':'MLA-NOTEBOOKS'}
descuentos_productos = pd.DataFrame(categoria_productos, index = ['domain_id']).T
for key in categoria_productos:
    #auxi = re.sub('MLA-', '', domain)
    cant_prod_cdescuento = (df[df['domain_id'] == categoria_productos[key] ].original_price.isnull()).value_counts()[0]
    cant_prod_categoria = len(df[df['domain_id'] == categoria_productos[key] ])
    print("La cantidad de ", str(key) ," con descuento es {}, de un total de {} y representa el {} %".format(
            cant_prod_cdescuento,
            cant_prod_categoria,
            round((cant_prod_cdescuento /cant_prod_categoria )*100,2)
            )
         )
    #asignacion de cantidad de descuentos
    descuentos_productos.loc[key,'ratio_prod_wdiscount'] = (cant_prod_cdescuento /cant_prod_categoria )
# Out:
# La cantidad de  televisores  con descuento es 81, de un total de 856 y representa el 9.46 %
# La cantidad de  celulares  con descuento es 121, de un total de 1025 y representa el 11.8 %
# La cantidad de  tablets  con descuento es 120, de un total de 1043 y representa el 11.51 %
# La cantidad de  notebooks  con descuento es 204, de un total de 1050 y representa el 19.43 %

# %% [markdown]
# Los productos con mayor cantidad de descuentos son las notebooks, en tanto que los que tienen menor ratio de descuentos son los televisores, basado en nuestra muestra.

# %%
# veamos como nos va con los descuentos
comparacion_descuentos = df[df['original_price'].notnull()][['price','original_price','domain_id']].copy()
# verifico que todos los datos sean fiables, debe coincidir con la cantidad de descuentos.
print('Cantidad de valores con descuento :',
      str( (comparacion_descuentos.original_price > comparacion_descuentos.price).sum() ))
print('Cantidad de valores sin descuento:',
      str( (comparacion_descuentos.original_price == comparacion_descuentos.price).sum() ))
# Out:
# Cantidad de valores con descuento : 507
# Cantidad de valores sin descuento: 38

# %% [markdown]
# Algo que podemos notar es que no deberian figurar valores donde *original_price == price*, ya que es una condicion de este dataset. En estos casos pudo haber siso un error durante la carga.

# %%
# Para conocer el promedio de descuestos necesito solamente considerar aquellos que realmente tienen descuento
comparacion_descuentos = comparacion_descuentos[\
                        comparacion_descuentos['original_price']>comparacion_descuentos['price']]
# calculo el descuento general independientemente de la categoria
print('El porcentaje de descuento promedio para los productos en oferta(con descuentos) es de {}%'.format(\
    round(( (comparacion_descuentos.original_price.sum()-comparacion_descuentos.price.sum())/\
    comparacion_descuentos.original_price.sum())*100, 2) ))
# calculo el descuento para las categorias de interes
for key in categoria_productos:
    descuento = (comparacion_descuentos[comparacion_descuentos['domain_id']==categoria_productos[key]].original_price.sum()-\
                 comparacion_descuentos[comparacion_descuentos['domain_id']==categoria_productos[key]].price.sum() )/\
                 comparacion_descuentos[comparacion_descuentos['domain_id']==categoria_productos[key]].original_price.sum()
    print('El porcentaje de descuento promedio de la categoria ', str(key) ,' es de {}%'.format(
            round(descuento*100,2)
            )
         )
    #asignacion de cantidad de descuentos
    descuentos_productos.loc[key,'prom_discount'] = descuento
# Out:
# El porcentaje de descuento promedio para los productos en oferta(con descuentos) es de 15.7%
# El porcentaje de descuento promedio de la categoria  televisores  es de 11.9%
# El porcentaje de descuento promedio de la categoria  celulares  es de 12.26%
# El porcentaje de descuento promedio de la categoria  tablets  es de 18.86%
# El porcentaje de descuento promedio de la categoria  notebooks  es de 17.05%

# %%
descuentos_productos
# Out:
#                    domain_id  ratio_prod_wdiscount  prom_discount
# televisores  MLA-TELEVISIONS              0.094626       0.119000
# celulares     MLA-CELLPHONES              0.118049       0.122562
# tablets          MLA-TABLETS              0.115053       0.188577
# notebooks      MLA-NOTEBOOKS              0.194286       0.170487

# %%
x_2plot = np.array(descuentos_productos.index)
y_2plot1 = np.array(descuentos_productos.iloc[:,1].apply(lambda x: round(x,2)))
y_2plot2 = np.array(descuentos_productos.iloc[:,2].apply(lambda x: round(x,2)))

xcoord4 = range(0,4)
xi = range(len(xcoord4))
yi = range

annotations1 = [dict(x=xi-0.2,y=yi ,text=str(yi*100)+'%',xanchor='auto',yanchor='bottom',showarrow=False,
                    ) for xi, yi in zip(xcoord4, y_2plot1)]

annotations2 = [dict(x=xi+0.2,y=yi ,text=str(yi*100)+'%',xanchor='auto',yanchor='bottom',showarrow=False,
                    ) for xi, yi in zip(xcoord4, y_2plot2)]

annotations = annotations1 + annotations2

trace1 = go.Bar(x=x_2plot, y=y_2plot1, textposition='auto', name='% prod. con descuento', marker_color='#1f77b4',)
trace2 = go.Bar(x=x_2plot, y=y_2plot2, textposition='auto', name='Descuento promedio', marker_color='#00EA65')

data = [trace1, trace2]
layout = go.Layout(barmode='group',annotations=annotations, xaxis_tickangle=-45)
fig = go.Figure(data=data, layout=layout)
fig.update_layout(title='Porcentaje de productos con descuentos y descuento promedio por categoria'\
                  ,plot_bgcolor= 'whitesmoke',autosize=True)
fig.update_yaxes(tickformat=',.0%',range=[0.0,0.35], constrain="domain")
fig.show('svg')

# %% [markdown]
# Continuando con el analisis del data set, encontramos que una manera de manejar los nulos de *original_price* es reemplazarlos por el valor original, y si bien esta columna a futuro podria no servinos debido a su fuerte correlacion con *price*, servira para determinar el descuento aplicado sobre el producto, si lo hay.

# %%
categoria_productos[key]
# Out:
# 'MLA-NOTEBOOKS'

# %%
# veamos la cantidad de productos usados que hay
print('La cantidad de productos usados en las publicaciones es de {}, que respresenta el {}% de las publicaciones'.format(
    len(df[df['condition']=='used']), round(len(df[df['condition']=='used'])/len(df), 2)*100 ))

for key in categoria_productos:
    cant_prod_usados = len(df[(df['condition']=='used') & (df['domain_id'] == categoria_productos[key])])
    cant_prod_categoria = len(df[df['domain_id'] == categoria_productos[key] ])
    print("La cantidad de ", str(key) ," usados es de {}, de un total de {} y representa el {} %".format(
            cant_prod_usados,
            cant_prod_categoria,
            round((cant_prod_usados /cant_prod_categoria )*100,2)
            )
         )
    #asignacion de cantidad de descuentos
    #descuentos_productos.loc[key,'productos nuevos'] = (cant_prod_cdescuento /cant_prod_categoria )
# Out:
# La cantidad de productos usados en las publicaciones es de 280, que respresenta el 7.000000000000001% de las publicaciones
# La cantidad de  televisores  usados es de 75, de un total de 856 y representa el 8.76 %
# La cantidad de  celulares  usados es de 29, de un total de 1025 y representa el 2.83 %
# La cantidad de  tablets  usados es de 172, de un total de 1043 y representa el 16.49 %
# La cantidad de  notebooks  usados es de 4, de un total de 1050 y representa el 0.38 %

# %% [markdown]
# Es interesante observar que la mayor parte de los productos son nuevos, en un 94%.
# De los cuales las tables son los productos que tienen mayor porcentaje de productos usados.

# %% [markdown]
# <a href="#top">Back to Index</a>
# <a id="2"></a>
# ### 2) Identificado data extra (*Get the Data*)
# <a id="2.1"></a>
# #### 2.1) Extraccion de datos extra

# %% [markdown]
# El data set obtenido de los *results* de la consulta existen ciertos campos referidos tanto al proveedor, su historia y rating, entre otros, que son diccionarios contenidos en una columna del dataframe. Se identificarán las mismas, y mediante una función “expandiremos” dicho data set. Esto en medida que los valores sean significativos al modelo de negocio, en función de mi propio entendimiento.

# %%
# quiero explorar el contenido del diccionario que contienen algunas columnas
pd.DataFrame(list(df.seller)).sample(5)
# Out:
#              id                                          permalink  \
# 70    230369815    http://perfil.mercadolibre.com.ar/PANTEROFICIAL
# 405     3696089  http://perfil.mercadolibre.com.ar/VENTAS_TECNO...
# 1902  125095349   http://perfil.mercadolibre.com.ar/DINATECHONLINE
# 940   415834705  http://perfil.mercadolibre.com.ar/ELECTROSERVICE3
# 620   379980987        http://perfil.mercadolibre.com.ar/365+STORE
#
#                   registration_date  car_dealer  real_estate_agency  \
# 70    2016-10-04T14:44:18.000-04:00       False               False
# 405   2007-01-24T15:40:38.000-04:00       False               False
# 1902  2012-09-25T09:39:25.000-04:00       False               False
# 940   2019-03-13T09:35:11.000-04:00       False               False
# 620   2018-11-22T15:05:59.000-04:00       False               False
#
#                                                    tags  \
# 70    [normal, user_info_verified, eshop, mshops, me...
# 405   [normal, user_info_verified, eshop, mshops, me...
# 1902  [normal, user_info_verified, mshops, credits_p...
# 940   [normal, user_info_verified, eshop, mshops, cr...
# 620   [normal, user_info_verified, credits_profile, ...
#
#                                       seller_reputation  \
# 70    {'transactions': {'total': 4374, 'canceled': 2...
# 405   {'transactions': {'total': 104804, 'canceled':...
# 1902  {'transactions': {'total': 22176, 'canceled': ...
# 940   {'transactions': {'total': 634, 'canceled': 88...
# 620   {'transactions': {'total': 3155, 'canceled': 3...
#
#                                                   eshop
# 70    {'nick_name': 'PANTEROFICIAL', 'eshop_rubro': ...
# 405   {'nick_name': 'VENTAS_TECNOCENTER', 'eshop_rub...
# 1902                                                NaN
# 940   {'nick_name': 'ELECTROSERVICE3', 'eshop_rubro'...
# 620                                                 NaN

# %%
def extrac_new_DF_from_colum(df_2work, column_2work, option =1):
    '''Debido a la naturaleza de extraccion de datos de las APIs para evitar colapsar el servicio, en oportunidades
    hay diccionarios en alguna de las columnas al tratarse de archivos tipo json()
    con esta funcion indicamos el DF, y la columna de interes para devolver un nuevo dataframe
    df_2work => DataFrame de pandas
    colum_2work => 'string
    option = 1 o 2 devuelve un dataframe con y sin el atributo column_2work en el dataframe'''
    if option == 1:
        return pd.DataFrame( list(df_2work[column_2work]) ) #para probar, pero sin dropear la columna
    elif option == 2:
        # alternativa para expandir el dataframe en aquellas columnas que se duplican, me ahorro de pasos
        # con pop extraigola columna de interes para no dropear en otro paso
        return pd.concat([df_2work.drop([column_2work], axis=1), df_2work[column_2work].apply(pd.Series)], axis=1)

# %%
df = extrac_new_DF_from_colum(df, 'seller', 2)

# %% [markdown]
# Uno de los topicos interesantes es la reputacion del vendedor, *seller_reputation*

# %%
df2 = extrac_new_DF_from_colum(df, 'seller_reputation', 1)

# %%
df2
# Out:
#                                            transactions power_seller_status  \
# 0     {'total': 637695, 'canceled': 29475, 'period':...            platinum
# 1     {'total': 637695, 'canceled': 29475, 'period':...            platinum
# 2     {'total': 637695, 'canceled': 29475, 'period':...            platinum
# 3     {'total': 637695, 'canceled': 29475, 'period':...            platinum
# 4     {'total': 637695, 'canceled': 29475, 'period':...            platinum
# ...                                                 ...                 ...
# 4160  {'total': 130059, 'canceled': 7232, 'period': ...            platinum
# 4161  {'total': 40630, 'canceled': 2037, 'period': '...            platinum
# 4162  {'total': 130059, 'canceled': 7232, 'period': ...            platinum
# 4163  {'total': 25158, 'canceled': 1068, 'period': '...            platinum
# 4164  {'total': 101071, 'canceled': 5403, 'period': ...            platinum
#
#                                                 metrics level_id  \
# 0     {'claims': {'rate': 0.0087, 'value': 1095, 'pe...  5_green
# 1     {'claims': {'rate': 0.0087, 'value': 1095, 'pe...  5_green
# 2     {'claims': {'rate': 0.0087, 'value': 1095, 'pe...  5_green
# 3     {'claims': {'rate': 0.0087, 'value': 1095, 'pe...  5_green
# 4     {'claims': {'rate': 0.0087, 'value': 1095, 'pe...  5_green
# ...                                                 ...      ...
# 4160  {'claims': {'rate': 0.0086, 'value': 253, 'per...  5_green
# 4161  {'claims': {'rate': 0.0106, 'value': 64, 'peri...  5_green
# 4162  {'claims': {'rate': 0.0086, 'value': 253, 'per...  5_green
# 4163  {'claims': {'rate': 0.0152, 'value': 58, 'peri...  5_green
# 4164  {'claims': {'rate': 0.0107, 'value': 159, 'per...  5_green
#
#      protection_end_date real_level
# 0                    NaN        NaN
# 1                    NaN        NaN
# 2                    NaN        NaN
# 3                    NaN        NaN
# 4                    NaN        NaN
# ...                  ...        ...
# 4160                 NaN        NaN
# 4161                 NaN        NaN
# 4162                 NaN        NaN
# 4163                 NaN        NaN
# 4164                 NaN        NaN
#
# [4165 rows x 6 columns]

# %%
df2 = extrac_new_DF_from_colum(df2, 'transactions', 2)

# %%
df2.head()
# Out:
#   power_seller_status                                            metrics  \
# 0            platinum  {'claims': {'rate': 0.0087, 'value': 1095, 'pe...
# 1            platinum  {'claims': {'rate': 0.0087, 'value': 1095, 'pe...
# 2            platinum  {'claims': {'rate': 0.0087, 'value': 1095, 'pe...
# 3            platinum  {'claims': {'rate': 0.0087, 'value': 1095, 'pe...
# 4            platinum  {'claims': {'rate': 0.0087, 'value': 1095, 'pe...
#
#   level_id protection_end_date real_level   total  canceled    period  \
# 0  5_green                 NaN        NaN  637695     29475  historic
# 1  5_green                 NaN        NaN  637695     29475  historic
# 2  5_green                 NaN        NaN  637695     29475  historic
# 3  5_green                 NaN        NaN  637695     29475  historic
# 4  5_green                 NaN        NaN  637695     29475  historic
#
#                                              ratings  completed
# 0  {'negative': 0.06, 'positive': 0.93, 'neutral'...     608220
# 1  {'negative': 0.06, 'positive': 0.93, 'neutral'...     608220
# 2  {'negative': 0.06, 'positive': 0.93, 'neutral'...     608220
# 3  {'negative': 0.06, 'positive': 0.93, 'neutral'...     608220
# 4  {'negative': 0.06, 'positive': 0.93, 'neutral'...     608220

# %%
df2 = extrac_new_DF_from_colum(df2, 'ratings', 2)
df2 = extrac_new_DF_from_colum(df2, 'metrics', 2)

# %%
df2.sample(5)
# Out:
#      power_seller_status level_id protection_end_date real_level  total  \
# 842             platinum  5_green                 NaN        NaN   5380
# 1740                None  5_green                 NaN        NaN     66
# 1952              silver  5_green                 NaN        NaN    555
# 1065            platinum  5_green                 NaN        NaN  13831
# 3033                None  5_green                 NaN        NaN     11
#
#       canceled    period  completed  negative  positive  neutral  \
# 842        356  historic       5024      0.02      0.96     0.02
# 1740        11  historic         55      0.00      0.99     0.01
# 1952        70  historic        485      0.03      0.96     0.01
# 1065       682  historic      13149      0.04      0.94     0.02
# 3033         2  historic          9      0.00      1.00     0.00
#
#                                                  claims  \
# 842   {'rate': 0.0176, 'value': 21, 'period': '60 da...
# 1740      {'rate': 0, 'value': 2, 'period': '365 days'}
# 1952       {'rate': 0, 'value': 2, 'period': '60 days'}
# 1065  {'rate': 0.0073, 'value': 20, 'period': '60 da...
# 3033      {'rate': 0, 'value': 0, 'period': '365 days'}
#
#                                   delayed_handling_time  \
# 842   {'rate': 0.0592, 'value': 64, 'period': '60 da...
# 1740  {'rate': 0.0217, 'value': 1, 'period': '365 da...
# 1952     {'rate': 0.1, 'value': 6, 'period': '60 days'}
# 1065       {'rate': 0, 'value': 0, 'period': '60 days'}
# 3033      {'rate': 0, 'value': 0, 'period': '365 days'}
#
#                                          sales  \
# 842   {'period': '60 days', 'completed': 1122}
# 1740   {'period': '365 days', 'completed': 55}
# 1952    {'period': '60 days', 'completed': 64}
# 1065  {'period': '60 days', 'completed': 2633}
# 3033    {'period': '365 days', 'completed': 9}
#
#                                       cancellations
# 842    {'rate': 0, 'value': 0, 'period': '60 days'}
# 1740  {'rate': 0, 'value': 0, 'period': '365 days'}
# 1952   {'rate': 0, 'value': 0, 'period': '60 days'}
# 1065   {'rate': 0, 'value': 0, 'period': '60 days'}
# 3033  {'rate': 0, 'value': 0, 'period': '365 days'}

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4165 entries, 0 to 4164
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   power_seller_status    3514 non-null   object
#  1   level_id               4068 non-null   object
#  2   protection_end_date    379 non-null    object
#  3   real_level             379 non-null    object
#  4   total                  4165 non-null   int64
#  5   canceled               4165 non-null   int64
#  6   period                 4165 non-null   object
#  7   completed              4165 non-null   int64
#  8   negative               4165 non-null   float64
#  9   positive               4165 non-null   float64
#  10  neutral                4165 non-null   float64
#  11  claims                 4165 non-null   object
#  12  delayed_handling_time  4165 non-null   object
#  13  sales                  4165 non-null   object
#  14  cancellations          4165 non-null   object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 488.2+ KB

# %% [markdown]
# En esta instancia se han obtenido datos interesantes como la cantidad de ventas concretadas *completed*, las ventas canceladas *canceled* y el totas de los pedidos (la suma de las anteriores)
#
# Además, del rate que es un porcentual y puede ser *negative, positive* o *neutral*.
#
# Como en ningun momento he dropeado valores, eliminado registros, o más alla del *reset_index* aplicado en la generacion del dataframe de partida df, puedo mergear el data set *df* con *df2*. Por el momento seguire explorando el dataset

# %%
extrac_new_DF_from_colum(df, 'address', 1)
# Out:
#      state_id       state_name           city_id      city_name
# 0        AR-B     Buenos Aires              None   Villa Celina
# 1        AR-B     Buenos Aires              None   Villa Celina
# 2        AR-B     Buenos Aires              None   Villa Celina
# 3        AR-B     Buenos Aires              None   Villa Celina
# 4        AR-B     Buenos Aires              None   Villa Celina
# ...       ...              ...               ...            ...
# 4160     AR-C  Capital Federal  TUxBQlZJTDcwOTla  Villa Urquiza
# 4161     AR-B     Buenos Aires              None     San Martin
# 4162     AR-C  Capital Federal  TUxBQlZJTDcwOTla  Villa Urquiza
# 4163     AR-C  Capital Federal  TUxBQlZJTDQyMjBa   Villa Crespo
# 4164     AR-C  Capital Federal  TUxBQkNBQjM4MDda      Caballito
#
# [4165 rows x 4 columns]

# %% [markdown]
# Incluso hay otra columna con atributos similares

# %%
extrac_new_DF_from_colum(df, 'seller_address', 1)
# Out:
#      id comment address_line zip_code                            country  \
# 0                                      {'id': 'AR', 'name': 'Argentina'}
# 1                                      {'id': 'AR', 'name': 'Argentina'}
# 2                                      {'id': 'AR', 'name': 'Argentina'}
# 3                                      {'id': 'AR', 'name': 'Argentina'}
# 4                                      {'id': 'AR', 'name': 'Argentina'}
# ...  ..     ...          ...      ...                                ...
# 4160                                   {'id': 'AR', 'name': 'Argentina'}
# 4161                                   {'id': 'AR', 'name': 'Argentina'}
# 4162                                   {'id': 'AR', 'name': 'Argentina'}
# 4163                                   {'id': 'AR', 'name': 'Argentina'}
# 4164                                   {'id': 'AR', 'name': 'Argentina'}
#
#                                           state  \
# 0        {'id': 'AR-B', 'name': 'Buenos Aires'}
# 1        {'id': 'AR-B', 'name': 'Buenos Aires'}
# 2        {'id': 'AR-B', 'name': 'Buenos Aires'}
# 3        {'id': 'AR-B', 'name': 'Buenos Aires'}
# 4        {'id': 'AR-B', 'name': 'Buenos Aires'}
# ...                                         ...
# 4160  {'id': 'AR-C', 'name': 'Capital Federal'}
# 4161     {'id': 'AR-B', 'name': 'Buenos Aires'}
# 4162  {'id': 'AR-C', 'name': 'Capital Federal'}
# 4163  {'id': 'AR-C', 'name': 'Capital Federal'}
# 4164  {'id': 'AR-C', 'name': 'Capital Federal'}
#
#                                                    city latitude longitude
# 0                  {'id': None, 'name': 'Villa Celina'}
# 1                  {'id': None, 'name': 'Villa Celina'}
# 2                  {'id': None, 'name': 'Villa Celina'}
# 3                  {'id': None, 'name': 'Villa Celina'}
# 4                  {'id': None, 'name': 'Villa Celina'}
# ...                                                 ...      ...       ...
# 4160  {'id': 'TUxBQlZJTDcwOTla', 'name': 'Villa Urqu...
# 4161                 {'id': None, 'name': 'San Martin'}
# 4162  {'id': 'TUxBQlZJTDcwOTla', 'name': 'Villa Urqu...
# 4163  {'id': 'TUxBQlZJTDQyMjBa', 'name': 'Villa Cres...
# 4164    {'id': 'TUxBQkNBQjM4MDda', 'name': 'Caballito'}
#
# [4165 rows x 9 columns]

# %% [markdown]
# Como se puede apreciar *seller_address* tiene contenido redundante comparado con *address* por lo tanto solo expandire el data set original *df* para address.
# Se puede rescatar de la misma *state_name, city_name* ya que el resto del contenido sera redundante, o no aporta valor agregado.

# %%
df = extrac_new_DF_from_colum(df, 'address', 2)

# %%
# exploremos un poco el contenido del origen de las publicaciones
localizaciones = df[['state_name','city_name','domain_id']].copy()
localizaciones
# Out:
#            state_name      city_name        domain_id
# 0        Buenos Aires   Villa Celina  MLA-TELEVISIONS
# 1        Buenos Aires   Villa Celina  MLA-TELEVISIONS
# 2        Buenos Aires   Villa Celina  MLA-TELEVISIONS
# 3        Buenos Aires   Villa Celina  MLA-TELEVISIONS
# 4        Buenos Aires   Villa Celina  MLA-TELEVISIONS
# ...               ...            ...              ...
# 4160  Capital Federal  Villa Urquiza    MLA-NOTEBOOKS
# 4161     Buenos Aires     San Martin    MLA-NOTEBOOKS
# 4162  Capital Federal  Villa Urquiza    MLA-NOTEBOOKS
# 4163  Capital Federal   Villa Crespo    MLA-NOTEBOOKS
# 4164  Capital Federal      Caballito    MLA-NOTEBOOKS
#
# [4165 rows x 3 columns]

# %%
loc_2plot = (df.groupby('state_name')['domain_id'].agg(['count'])).sort_values(by = 'count', ascending=False)
xx = np.array(loc_2plot.index)
yy = np.array(loc_2plot)

fig = px.bar(x= xx, y=yy, title = 'Publicaciones por provincia')
fig.update_layout(
    xaxis_title="Provincias (state)",
    yaxis_title="Publicaciones",
    plot_bgcolor= 'whitesmoke',autosize=True)
fig.update_traces(texttemplate=list(loc_2plot['count']), textposition='outside')
fig.update_yaxes(range=[0.0,3000.0], constrain="domain")
fig.show('svg')

# %%
caba_2plot = (df[df['state_name']=='Capital Federal'].groupby('city_name')['domain_id'].agg(['count'])).\
    sort_values(by = 'count', ascending=False)
xx = np.array(caba_2plot.index)
yy = np.array(caba_2plot)

fig = px.bar(x= xx, y=yy, title = 'Publicaciones por barrio en CABA')
fig.update_layout(
    xaxis_title='',
    yaxis_title='Publicaciones',
    plot_bgcolor= 'whitesmoke',autosize=True)
fig.update_yaxes(range=[0.0,350.0], constrain="domain")
fig.show('svg')

# %%
# top10 barrios con mas publicaciones
caba_2plot.iloc[range(0,10),:]
# Out:
#                   count
# city_name
# Villa Crespo        332
# Belgrano            183
# Barracas            182
# Balvanera           166
# Parque Patricios    165
# Monserrat           157
# San Nicolás         142
# Villa Urquiza       113
# Caballito            83
# Palermo              81

# %% [markdown]
# Otro atributo intersante para rescatar es el envio o *shipping*, en algunas oportunidades tomamos en cuenta las condiciones de envio para realizar una compra, aunque por el precio medio de la mayoria de estos, es probable que la mayoria sea gratuito (free)

# %%
df3 = extrac_new_DF_from_colum(df, 'shipping', 1)
df3
# Out:
#       free_shipping mode                                        tags  \
# 0              True  me2      [fulfillment, mandatory_free_shipping]
# 1              True  me2      [fulfillment, mandatory_free_shipping]
# 2              True  me2      [fulfillment, mandatory_free_shipping]
# 3              True  me2      [fulfillment, mandatory_free_shipping]
# 4              True  me2      [fulfillment, mandatory_free_shipping]
# ...             ...  ...                                         ...
# 4160           True  me2  [self_service_in, mandatory_free_shipping]
# 4161           True  me2  [self_service_in, mandatory_free_shipping]
# 4162           True  me2  [self_service_in, mandatory_free_shipping]
# 4163           True  me2  [self_service_in, mandatory_free_shipping]
# 4164           True  me2  [self_service_in, mandatory_free_shipping]
#
#       logistic_type  store_pick_up
# 0       fulfillment          False
# 1       fulfillment          False
# 2       fulfillment          False
# 3       fulfillment          False
# 4       fulfillment          False
# ...             ...            ...
# 4160  cross_docking          False
# 4161  cross_docking          False
# 4162  cross_docking          False
# 4163  cross_docking          False
# 4164  cross_docking          False
#
# [4165 rows x 5 columns]

# %% [markdown]
# En este caso no expandi directamente el data set ya que existe otra columna con el nombre *tags*.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4165 entries, 0 to 4164
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   free_shipping  4165 non-null   bool
#  1   mode           4165 non-null   object
#  2   tags           4165 non-null   object
#  3   logistic_type  4165 non-null   object
#  4   store_pick_up  4165 non-null   bool
# dtypes: bool(2), object(3)
# memory usage: 105.9+ KB

# %%
df3['mode'].value_counts()
# Out:
# me2              3758
# not_specified     229
# custom            169
# me1                 9
# Name: mode, dtype: int64

# %%
df3['logistic_type'].value_counts()
# Out:
# cross_docking    2042
# drop_off          883
# xd_drop_off       485
# fulfillment       348
# not_specified     229
# custom            169
# default             9
# Name: logistic_type, dtype: int64

# %%
df3['store_pick_up'].value_counts()
# Out:
# False    3950
# True      215
# Name: store_pick_up, dtype: int64

# %% [markdown]
# De todos estos datos posiblemente el que mas vea un usuario que va a realizar una compra sea si el envio es gratuito o no, no necesariamente todas estas condiciones, pero dejare esto para una instancia de modelado.

# %% [markdown]
# <a href="#top">Back to Index</a>
# <a id="3"></a>
# ### 3) Conclusion de Parte I
# <a id="3.1"></a>
# #### 3.1) Preparacion del data set final

# %% [markdown]
# Preparo el data set final que empleare en la PARTE II instancia de modelado, donde se seguira tratando el data set final obtenido en esta instancia pero enfocando para su uso en un algoritmo, por lo tanto pasara por las intancias de limpieza, feature seleccition y feature engineering.

# %%
# concatenamos los datasets obtenidos hasta el momento
df_part1 = pd.concat([df, df2, df3], axis = 1)
df_part1.shape
# Out:
# (4165, 63)

# %%
df_part1.to_excel('./data/data_part1.xlsx', index= False)
df_part1.to_csv('./data/data_part1.csv', index= False)

# %% [markdown]
# <a id="3.2"></a>
# #### 3.2) Comentarios finales

# %% [markdown]
# Como se pudo observar en el analisis exploratorio realizado, se pudo ver los siguiente:
# * Las busquedas pueden ser mas o menos precisas en funcion del tag de la busqueda, por ejemplo *tv 4k* trajo aparejada una mayor cantidad de categorias (distintos *domain_id*), no paso asi con las demas
# * El descuento promedio en las publicaciones es del 15%, y hay un 17% de productos de descuentos en la parte electronica (de esta muestra).
# * Las notebooks son el producto con mayor cantidad de productos en descuento, sin embargo las tablets son las que ofrecen mayor descuento promedio en su precio de publicado
#
#
# Para más detalles visitar el repositorio <a href = 'https://github.com/Mattzvl/EDA_API_ML'>EDA_API_MELI</a> que contiene este archivo y la parte II

# %%
#pip freeze > requirements.txt
